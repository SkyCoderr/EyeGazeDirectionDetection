# %% [markdown]
# # **Import**

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
import pickle
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # **Loading Data Sets**

# %%
X_train_pickle = open('/content/drive/My Drive/Data/X_train.pickle', 'rb')
X_train = pickle.load(X_train_pickle)

y_train_pickle = open('/content/drive/My Drive/Data/y_train.pickle', 'rb')
y_train = pickle.load(y_train_pickle)

X_test_pickle = open('/content/drive/My Drive/Data/X_test.pickle', 'rb')
X_test = pickle.load(X_test_pickle)

y_test_pickle = open('/content/drive/My Drive/Data/y_test.pickle', 'rb')
y_test = pickle.load(y_test_pickle)

# %% [markdown]
# # **Training**

# %%
model = Sequential()

model.add(Conv2D(64, (3,3), input_shape=(100, 100, 1)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(128, (3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(128, (3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64, (3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))

model.add(Dense(36))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy', optimizer = tf.keras.optimizers.RMSprop(lr=0.0001), metrics=['accuracy'])

model.fit(X_train, y_train, epochs=40, batch_size=40, validation_split=0.1)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0812 02:15:15.032003 139737908471680 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Train on 4227 samples, validate on 470 samples
# Epoch 1/40
# 4227/4227 [==============================] - 165s 39ms/sample - loss: 3.5776 - acc: 0.0300 - val_loss: 3.5667 - val_acc: 0.0234
# Epoch 2/40
# 4227/4227 [==============================] - 165s 39ms/sample - loss: 3.5602 - acc: 0.0310 - val_loss: 3.5516 - val_acc: 0.0255
# Epoch 3/40
# 4227/4227 [==============================] - 166s 39ms/sample - loss: 3.5329 - acc: 0.0468 - val_loss: 3.5031 - val_acc: 0.0574
# Epoch 4/40
# 4227/4227 [==============================] - 166s 39ms/sample - loss: 3.4454 - acc: 0.0830 - val_loss: 3.3491 - val_acc: 0.1255
# Epoch 5/40
# 4227/4227 [==============================] - 166s 39ms/sample - loss: 3.2743 - acc: 0.1169 - val_loss: 3.2112 - val_acc: 0.1000
# Epoch 6/40
# 4227/4227 [==============================] - 166s 39ms/sample - loss: 3.0682 - acc: 0.1595 - val_loss: 3.0786 - val_acc: 0.1426
# Epoch 7/40
# 4227/4227 [==============================] - 167s 39ms/sample - loss: 2.8397 - acc: 0.2124 - val_loss: 2.6495 - val_acc: 0.2936
# Epoch 8/40
# 4227/4227 [==============================] - 166s 39ms/sample - loss: 2.5799 - acc: 0.2666 - val_loss: 2.4413 - val_acc: 0.3106
# Epoch 9/40
# 4227/4227 [==============================] - 166s 39ms/sample - loss: 2.3605 - acc: 0.3277 - val_loss: 2.1875 - val_acc: 0.4064
# Epoch 10/40
# 4227/4227 [==============================] - 167s 39ms/sample - loss: 2.1398 - acc: 0.3676 - val_loss: 2.0181 - val_acc: 0.3936
# Epoch 11/40
# 4227/4227 [==============================] - 167s 39ms/sample - loss: 1.9741 - acc: 0.4050 - val_loss: 1.8767 - val_acc: 0.4085
# Epoch 12/40
# 4227/4227 [==============================] - 167s 39ms/sample - loss: 1.8383 - acc: 0.4341 - val_loss: 1.7247 - val_acc: 0.4830
# Epoch 13/40
# 4227/4227 [==============================] - 167s 39ms/sample - loss: 1.7077 - acc: 0.4807 - val_loss: 1.6607 - val_acc: 0.4511
# Epoch 14/40
# 4227/4227 [==============================] - 166s 39ms/sample - loss: 1.6209 - acc: 0.5025 - val_loss: 1.5646 - val_acc: 0.4745
# Epoch 15/40
# 4227/4227 [==============================] - 166s 39ms/sample - loss: 1.5242 - acc: 0.5254 - val_loss: 1.4479 - val_acc: 0.5149
# Epoch 16/40
# 4227/4227 [==============================] - 166s 39ms/sample - loss: 1.4507 - acc: 0.5515 - val_loss: 1.5945 - val_acc: 0.4894
# Epoch 17/40
# 4227/4227 [==============================] - 165s 39ms/sample - loss: 1.3619 - acc: 0.5803 - val_loss: 1.3896 - val_acc: 0.5660
# Epoch 18/40
# 4227/4227 [==============================] - 166s 39ms/sample - loss: 1.3011 - acc: 0.5907 - val_loss: 1.2966 - val_acc: 0.5872
# Epoch 19/40
# 4227/4227 [==============================] - 166s 39ms/sample - loss: 1.2417 - acc: 0.6108 - val_loss: 1.3368 - val_acc: 0.5213
# Epoch 20/40
# 4227/4227 [==============================] - 166s 39ms/sample - loss: 1.1774 - acc: 0.6272 - val_loss: 1.3464 - val_acc: 0.5553
# Epoch 21/40
# 4227/4227 [==============================] - 165s 39ms/sample - loss: 1.1276 - acc: 0.6425 - val_loss: 1.0936 - val_acc: 0.6404
# Epoch 22/40
# 4227/4227 [==============================] - 166s 39ms/sample - loss: 1.0885 - acc: 0.6579 - val_loss: 1.5748 - val_acc: 0.5000
# Epoch 23/40
# 4227/4227 [==============================] - 166s 39ms/sample - loss: 1.0373 - acc: 0.6664 - val_loss: 1.0276 - val_acc: 0.6894
# Epoch 24/40
# 4227/4227 [==============================] - 167s 39ms/sample - loss: 0.9803 - acc: 0.6899 - val_loss: 1.3595 - val_acc: 0.5574
# Epoch 25/40
# 4227/4227 [==============================] - 166s 39ms/sample - loss: 0.9543 - acc: 0.7005 - val_loss: 1.0002 - val_acc: 0.6957
# Epoch 26/40
# 4227/4227 [==============================] - 165s 39ms/sample - loss: 0.9259 - acc: 0.7031 - val_loss: 0.9275 - val_acc: 0.6894
# Epoch 27/40
# 4227/4227 [==============================] - 165s 39ms/sample - loss: 0.8864 - acc: 0.7135 - val_loss: 0.8626 - val_acc: 0.7340
# Epoch 28/40
# 4227/4227 [==============================] - 167s 39ms/sample - loss: 0.8319 - acc: 0.7383 - val_loss: 0.9536 - val_acc: 0.6872
# Epoch 29/40
# 4227/4227 [==============================] - 167s 39ms/sample - loss: 0.8251 - acc: 0.7322 - val_loss: 1.0450 - val_acc: 0.6511
# Epoch 30/40
# 4227/4227 [==============================] - 167s 39ms/sample - loss: 0.7933 - acc: 0.7473 - val_loss: 0.8649 - val_acc: 0.7191
# Epoch 31/40
# 4227/4227 [==============================] - 167s 39ms/sample - loss: 0.7567 - acc: 0.7535 - val_loss: 1.4006 - val_acc: 0.5447
# Epoch 32/40
# 4227/4227 [==============================] - 167s 39ms/sample - loss: 0.7335 - acc: 0.7679 - val_loss: 0.7971 - val_acc: 0.7553
# Epoch 33/40
# 4227/4227 [==============================] - 166s 39ms/sample - loss: 0.7040 - acc: 0.7819 - val_loss: 0.8142 - val_acc: 0.7277
# Epoch 34/40
# 4227/4227 [==============================] - 166s 39ms/sample - loss: 0.6659 - acc: 0.7795 - val_loss: 0.8720 - val_acc: 0.6723
# Epoch 35/40
# 4227/4227 [==============================] - 167s 39ms/sample - loss: 0.6496 - acc: 0.7928 - val_loss: 0.7864 - val_acc: 0.7191
# Epoch 36/40
# 4227/4227 [==============================] - 167s 39ms/sample - loss: 0.6338 - acc: 0.7965 - val_loss: 0.7130 - val_acc: 0.7660
# Epoch 37/40
# 4227/4227 [==============================] - 167s 40ms/sample - loss: 0.6124 - acc: 0.7991 - val_loss: 0.6482 - val_acc: 0.7872
# Epoch 38/40
# 4227/4227 [==============================] - 167s 40ms/sample - loss: 0.5946 - acc: 0.8110 - val_loss: 0.7390 - val_acc: 0.7255
# Epoch 39/40
# 4227/4227 [==============================] - 167s 40ms/sample - loss: 0.5577 - acc: 0.8207 - val_loss: 0.5761 - val_acc: 0.8085
# Epoch 40/40
# 4227/4227 [==============================] - 167s 40ms/sample - loss: 0.5490 - acc: 0.8230 - val_loss: 0.6253 - val_acc: 0.7872

# %% [markdown]
# # **Model Evaluation**

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(loss)
print(accuracy)
# Out:
# 465/465 [==============================] - 5s 11ms/sample - loss: 0.5367 - acc: 0.8237
# 0.5367482691682796
# 0.8236559

# %% [markdown]
# # **Storing Model**

# %%
model.save('/content/drive/My Drive/Data/Models/model0/model0.h5')

# %% [markdown]
# # **Loading Model**

# %%
model = tf.keras.models.load_model('/content/drive/My Drive/Data/Models/model0/model0.h5')
model.save('/content/drive/My Drive/Data/Models/model0/model00.h5', include_optimizer=True)
